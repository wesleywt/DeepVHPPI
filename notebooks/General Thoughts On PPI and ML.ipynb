# %% [markdown]
# # General Thoughts on PPI prediction and Machine Learning
# ## Definition of an interaction
# PHI-base defines an interaction as: an observable function of one gene, on one host and on one tissue type [Urban, 2022](https://academic.oup.com/nar/article/50/D1/D837/6426057).
# ## Mimicry of host molecules by pathogens
# ### Date: 27-04-2022
# I have been thinking along the lines of this for a while now. If I am a pathogen, the molecules that I develop to infect the host should look closely like the normal proteins that usually use the receptors I am targeting. The article [Urban, 2022](https://academic.oup.com/nar/article/50/D1/D837/6426057) referenced an article where they discuss pathogen mimicry.
#
# If this is the case, then a machine learning model that is trained to predict host-host interactions could be fine-tuned with pathogenic data to predict host-pathogen interactions.
#
# ### Method
# I would think, you would train a model using a Transformer then reload the parameters and fine-tune this model using host-pathogen data. Perhaps with the better models I have now I should give this a go.
#
# * Another way to look at this is to fine functionally homologous proteins in pathogens and hosts. Could we classify similarity and family?
#
# * Could we create a dataset of pathogen target proteins, and their endogenous interactors? Then fine-tune this model with pathogenic proteins????

# %% [markdown]
# ## Loading Large Language Models from HuggingFace
# ### Date: 27-04-2022
# Since the ProtTrans models on HuggingFace use the same vocabulary as the Lanchintin models, I should see if I can load the pre-trained BERT models and perform the training on the host-pathogen datasets I have.
#
# Lanchintin has trained his own LMs but has not made them available.
#
# ### Some questions
# A big question when training the LMs is, did Lanchintin use the CNN attached to BERT when training the LMs. Did he first train the LMs then used the CNN + BERT to fine-tune the models. If it is the second case then I can use the ProTrans models directly from HuggingFace.

# %% [markdown]
# ## Ensemble Bacteria databases
# ### Date 27-04-2022
# PHI-base provides annotation of pathogen-host interactions in the Ensemble Bacteria databases.
#
# I need to see if I can download more PPIs particularly dealing with interactions between humans and bacteria to further extend the database I already have.

# %% [markdown]
# ## PHI-BASE
# ### Date 27-04-2022
# PHI-BASE is a multi-host pathogen interaction database, that has been curated. It contains plant, human and fungi interactions between pathogens. The interactions leads to a specific phenotypic effect.

# %%
import pandas as pd
phibase = pd.read_csv('../data/phi_base/phi-base_current.csv', sep=',', encoding='ISO-8859-1')
phibase.head()
# Out:
# C:\Users\wesle\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (22,25,26,29,30,37,45,46,47,50,51,53) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   Record ID PHI_MolConn_ID Protein ID source Protein ID Gene ID source  \
# 0  Record 1          PHI:3           Uniprot     P26215           EMBL
# 1  Record 2          PHI:7           Uniprot     P22287           EMBL
# 2  Record 3         PHI:12           Uniprot     Q01886           EMBL
# 3  Record 4         PHI:14           Uniprot     P0C017           EMBL
# 4  Record 5         PHI:14           Uniprot     P0C017           EMBL
#
#     Gene ID AA sequence NT sequence   Sequence Strain  Gene  ... Ref. detail  \
# 0  AAA79885                                     SB111  PGN1  ...         NaN
# 1  CAA42824                                    race 5  AVR9  ...         NaN
# 2  AAA33023                                     SB111  HTS1  ...         NaN
# 3  AAB09711                          clinical isolate  ADE2  ...         NaN
# 4  AAB09711                          clinical isolate  ADE2  ...         NaN
#
#   Author email                                           Comments  \
# 0          NaN  Expression during all infection stages. pathog...
# 1          NaN                                                NaN
# 2          NaN  pathogen formerly called Cochliobolus carbonum...
# 3          NaN                                                NaN
# 4          NaN                                                NaN
#
#      Author reference    Year Curation details  File name          Batch no.  \
# 0  Scott-Craig et al.  1990.0              NaN        NaN  PHI-base Vers.3.3
# 1      Van Kan et al.  1991.0              NaN        NaN  PHI-base Vers.3.3
# 2   Panaccione et al.  1992.0              NaN        NaN  PHI-base Vers.3.3
# 3      Perfect et al.  1993.0              NaN        NaN  PHI-base Vers.3.3
# 4      Perfect et al.  1993.0              NaN        NaN  PHI-base Vers.3.3
#
#    Curation date Curator organization
# 0          38476                 Rres
# 1          38476                 Rres
# 2          38476                 Rres
# 3          38476                 Rres
# 4          38476                 Rres
#
# [5 rows x 66 columns]

# %%
phibase
# Out:
#           Record ID PHI_MolConn_ID Protein ID source     Protein ID  \
# 0          Record 1          PHI:3           Uniprot         P26215
# 1          Record 2          PHI:7           Uniprot         P22287
# 2          Record 3         PHI:12           Uniprot         Q01886
# 3          Record 4         PHI:14           Uniprot         P0C017
# 4          Record 5         PHI:14           Uniprot         P0C017
# ...             ...            ...               ...            ...
# 18187  Record 18188       PHI:7054           Uniprot         P13470
# 18188  Record 18189       PHI:7055           Uniprot         P49331
# 18189  Record 18190       PHI:8088           Uniprot         Q8DUS1
# 18190  Record 18191       PHI:9976           Uniprot  no data found
# 18191  Record 18192       PHI:9976           Uniprot  no data found
#
#       Gene ID source     Gene ID AA sequence NT sequence   Sequence Strain  \
# 0               EMBL    AAA79885                                     SB111
# 1               EMBL    CAA42824                                    race 5
# 2               EMBL    AAA33023                                     SB111
# 3               EMBL    AAB09711                          clinical isolate
# 4               EMBL    AAB09711                          clinical isolate
# ...              ...         ...         ...         ...               ...
# 18187        Genbank  AE014940_2                                     UA159
# 18188        Genbank  AE014932_2                                     UA159
# 18189        Genbank  AE014924_6                                     UA159
# 18190        Genbank    AFM51859                                       NaN
# 18191        Genbank    AFM51859                                       NaN
#
#                  Gene  ...                                       Ref. detail  \
# 0                PGN1  ...                                               NaN
# 1                AVR9  ...                                               NaN
# 2                HTS1  ...                                               NaN
# 3                ADE2  ...                                               NaN
# 4                ADE2  ...                                               NaN
# ...               ...  ...                                               ...
# 18187            gtfC  ...        Infect Immun. 2016 Oct 17;84(11):3206-3219
# 18188            gtfD  ...        Infect Immun. 2016 Oct 17;84(11):3206-3219
# 18189  rgpf (SMU.830)  ...  J Bacteriol. 2017 Nov 14;199(24). pii: e00497-17
# 18190       Mbov_0503  ...                  Microorganisms. 2020 Jan 23;8(2)
# 18191       Mbov_0503  ...                  Microorganisms. 2020 Jan 23;8(2)
#
#                            Author email  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 18187           rmgraner@fop.unicamp.br
# 18188           rmgraner@fop.unicamp.br
# 18189  Robert_Quivey@urmc.rochester.edu
# 18190           aizhen@mail.hzau.edu.cn
# 18191           aizhen@mail.hzau.edu.cn
#
#                                                 Comments    Author reference  \
# 0      Expression during all infection stages. pathog...  Scott-Craig et al.
# 1                                                    NaN      Van Kan et al.
# 2      pathogen formerly called Cochliobolus carbonum...   Panaccione et al.
# 3                                                    NaN      Perfect et al.
# 4                                                    NaN      Perfect et al.
# ...                                                  ...                 ...
# 18187  UAcov showed increased exvivo survival in huma...      L A Alves 2016
# 18188  UAcov showed increased exvivo survival in huma...      L A Alves 2016
# 18189  The loss of rgpF caused a perturbation of memb...     C J Kovacs 2017
# 18190  Although Mbov_0503 disruption was only associa...          X Zhu 2020
# 18191  Although Mbov_0503 disruption was only associa...          X Zhu 2020
#
#          Year Curation details  \
# 0      1990.0              NaN
# 1      1991.0              NaN
# 2      1992.0              NaN
# 3      1993.0              NaN
# 4      1993.0              NaN
# ...       ...              ...
# 18187  2016.0          6 genes
# 18188  2016.0          6 genes
# 18189  2017.0           1 gene
# 18190  2020.0           1 gene
# 18191  2020.0           1 gene
#
#                                             File name          Batch no.  \
# 0                                                 NaN  PHI-base Vers.3.3
# 1                                                 NaN  PHI-base Vers.3.3
# 2                                                 NaN  PHI-base Vers.3.3
# 3                                                 NaN  PHI-base Vers.3.3
# 4                                                 NaN  PHI-base Vers.3.3
# ...                                               ...                ...
# 18187  Alves-2016-CovR regulates Streptococcus mutans         BATCH_067B
# 18188  Alves-2016-CovR regulates Streptococcus mutans         BATCH_067B
# 18189  Kovacs-2017-RgpF is required for maintenance o          BATCH_082
# 18190  Zhu-2020-Mbov_0503 Encodes a Novel Cytoadhesin         BATCH_099B
# 18191  Zhu-2020-Mbov_0503 Encodes a Novel Cytoadhesin         BATCH_099B
#
#        Curation date Curator organization
# 0              38476                 Rres
# 1              38476                 Rres
# 2              38476                 Rres
# 3              38476                 Rres
# 4              38476                 Rres
# ...              ...                  ...
# 18187         May-17                   MC
# 18188         May-17                   MC
# 18189         May-18                   MC
# 18190          43891                   MC
# 18191          43891                   MC
#
# [18192 rows x 66 columns]

# %% [markdown]
# ## Host species in Phibase

# %%
set(phibase['Host species'].values)
# Out:
# {'Acanthamoeba castellanii (no common name found)',
#  'Acanthamoeba polyphaga (no common name found)',
#  'Acipenser sinensis (related: chinese sturgeon)',
#  'Actinidia chinensis (no common name found)',
#  'Acyrthosiphon pisum (related: pea aphid)',
#  'Adalia bipunctata (related: two-spotted ladybird beetle)',
#  'Aedes aegypti (related: yellow fever mosquito)',
#  'Aeschynomene virginica (no common name found)',
#  'Agaricus bisporus (related: cultivated mushroom)',
#  'Ageratina adenophora (no common name found)',
#  'Allium cepa (related: onion)',
#  'Anas platyrhynchos (related: mallard)',
#  'Anguilla anguilla (related: european eel)',
#  'Anopheles stephensi (related: asian malaria mosquito)',
#  'Anthurium andraeanum (related: oilcloth flower)',
#  'Aphididae (related: aphids)',
#  'Apis mellifera (related: honey bee)',
#  'Apium graveolens (no common name found)',
#  'Arabidopsis thaliana (related: thale cress)',
#  'Arabidopsis thaliana (related: thale cress) (non-host bioassay: nicotiana benthamiana)',
#  'Arabidopsis thaliana (related: thale cress) (non-host bioassay: tobacco)',
#  'Arabidopsis thaliana (related: thale cress) (non-host bioassay: yeast)',
#  'Arachis hypogaea (related: peanut)',
#  'Artemia (related: brine shrimps)',
#  'Artemia franciscana (no common name found)',
#  'Artemia salina (no common name found)',
#  'Athelia rolfsii (no common name found)',
#  'Avena sativa (related: oat)',
#  'Avena strigosa (related: black oat)',
#  'Averrhoa carambola (no common name found)',
#  'Bombyx mori (related: domestic silkworm)',
#  'Bos taurus (related: cattle)',
#  'Brachypodium distachyon (related: stiff brome)',
#  'Brassica carinata (related: ethiopian mustard)',
#  'Brassica juncea (related: brown mustard)',
#  'Brassica napus (related: rape)',
#  'Brassica oleracea (no common name found)',
#  'Brassica rapa (related: field mustard)',
#  'Caenorhabditis elegans (related: roundworm)',
#  'Canis lupus (related: gray wolf)',
#  'Capsicum annuum (no common name found)',
#  'Capsicum frutescens (related: hot pepper)',
#  'Carassius carassius (related: crucian carp)',
#  'Castanea dentata (related: american chestnut)',
#  'Castanea mollissima (related: chinese chestnut)',
#  'Castanea sativa (related: chestnut)',
#  'Cavia porcellus (related: domestic guinea pig)',
#  'Chenopodium quinoa (related: quinoa)',
#  'Chinchilla chinchilla (related: short-tailed chinchilla)',
#  'Chinchilla lanigera (related: long-tailed chinchilla)',
#  'Chlorocebus aethiops (related: grivet)',
#  'Chrysanthemum x morifolium (related: mum)',
#  'Chrysoperla carnea (no common name found)',
#  'Cicer arietinum (related: chickpea)',
#  'Cichorium intybus (related: chicory)',
#  'Citrullus lanatus (related: wild melon)',
#  'Citrus (no common name found)',
#  'Citrus aurantiifolia (related: lime)',
#  'Citrus iyo (no common name found)',
#  'Citrus jambhiri (related: rough lemon)',
#  'Citrus limon (related: lemon)',
#  'Citrus limonia (related: mandarin lime)',
#  'Citrus reticulata (related: tangerine)',
#  'Citrus sinensis (related: sweet orange)',
#  'Citrus unshiu (related: satsuma mandarin)',
#  'Citrus x microcarpa (related: calamondin)',
#  'Citrus x paradisi (related: grapefruit)',
#  'Citrus x tangelo (related: tangelo)',
#  'Cotinus coggygria (related: smokebush)',
#  'Cotinus obovatus (no common name found)',
#  'Coturnix coromandelica (related: rain quail)',
#  'Crassostrea gigas (related: pacific oyster)',
#  'Crassostrea virginica (related: eastern oyster)',
#  'Cricetinae (related: hamsters)',
#  'Cucumis anguria (related: gherkin)',
#  'Cucumis melo (related: muskmelon)',
#  'Cucumis sativus (related: cucumber)',
#  'Cucurbita maxima (related: winter squash)',
#  'Cucurbita moschata (related: crookneck pumpkin)',
#  'Cucurbita pepo (no common name found)',
#  'Cunninghamia lanceolata (related: china fir)',
#  'Cynara cardunculus (related: wild artichoke)',
#  'Cynoglossus semilaevis (related: tongue sole)',
#  'Danio rerio (related: zebrafish)',
#  'Daphnia magna (no common name found)',
#  'Daucus carota (related: carrot)',
#  'Dianthus caryophyllus (related: clove pink)',
#  'Dictyostelium discoideum (related: amoeba)',
#  'Dictyostelium discoideum (related: amoeba)(non-host bioassay)',
#  'Drosophila melanogaster (related: fruit fly)',
#  'Dysdercus peruvianus (no common name found)',
#  'Eisenia fetida (related: common brandling worm)',
#  'Equus caballus (related: horse)',
#  'Eragrostis curvula (related: weeping love grass)',
#  'Festuca pratensis (related: meadow ryegrass)',
#  'Fragaria x ananassa (related: strawberry)',
#  'Galleria mellonella (related: greater wax moth)',
#  'Gallus gallus (related: chicken)',
#  'Gerbera (no common name found)',
#  'Gerbillinae (related: gerbils)',
#  'Glycine max (related: soybean)',
#  'Glycine max (related: soybean) (non-host bioassay: e. coli)',
#  'Glycine max (related: soybean) (non-host bioassay: n. benthamiana)',
#  'Glycine max (related: soybean) (non-host bioassay: yeast)',
#  'Gossypium barbadense (related: sea-island cotton)',
#  'Gossypium hirsutum (related: cotton)',
#  'Gryllus bimaculatus (related: two-spotted cricket)',
#  'Helianthus annuus (related: common sunflower)',
#  'Helicoverpa armigera (related: cotton bollworm)',
#  'Hevea brasiliensis (related: rubber tree)',
#  'Homo sapiens (related: human)',
#  'Hordeum vulgare (related: barley)',
#  'Ictalurus punctatus (related: channel catfish)',
#  'Ixodes scapularis (related: black-legged tick)',
#  "Kalanchoe daigremontiana (related: devil's backbone)",
#  'Lactuca sativa (related: garden lettuce)',
#  'Lemna minor (no common name found)',
#  'Lens culinaris (related: lentil)',
#  'Lethal pathogen phenotype',
#  'Lilium (no common name found)',
#  'Linum usitatissimum (related: flax)',
#  'Liriodendron chinense x liriodendron tulipifera (no common name found)',
#  'Locusta migratoria (related: migratory locust)',
#  'Lolium arundinaceum (related: tall fescue)',
#  'Lolium multiflorum (related: italian ryegrass)',
#  'Lolium perenne (related: perennial ryegrass)',
#  'Lutzomyia longipalpis (no common name found)',
#  'Macaca fascicularis (related: crab-eating macaque)',
#  'Macrosteles quadrilineatus (related: aster leafhopper)',
#  'Malus domestica (related: apple)',
#  'Malus prunifolia (no common name found)',
#  'Malus pumila (related: paradise apple)',
#  'Manduca sexta (related: tobacco hornworm)',
#  'Mangifera indica (related: mango)',
#  'Manihot esculenta (related: cassava)',
#  'Medicago sativa (related: alfalfa)',
#  'Medicago truncatula (related: barrel medic)',
#  'Meriones unguiculatus (related: mongolian gerbil)',
#  'Mesocricetus auratus (related: golden hamster)',
#  'Mus musculus (related: house mouse)',
#  'Musa acuminata (related: dwarf banana)',
#  'Musa x paradisiaca (related: banana)',
#  'Nerium oleander (related: common oleander)',
#  'Nicotiana benthamiana (no common name found)',
#  'Nicotiana benthamiana (no common name found)(non-host bioassay)',
#  'Nicotiana otophora (no common name found)',
#  'Nicotiana paniculata (no common name found)',
#  'Nicotiana sylvestris (related: wood tobacco)',
#  'Nicotiana tabacum (related: common tobacco)',
#  'Nicotiana tabacum (related: common tobacco) (non-host bioassay)',
#  'No host tests done',
#  'Olea europaea (related: common olive)',
#  'Oncorhynchus kisutch (related: coho salmon)',
#  'Oncorhynchus mykiss (related: rainbow trout)',
#  'Oreochromis niloticus (related: nile tilapia)',
#  'Oryctolagus cuniculus (related: rabbit)',
#  'Oryza sativa (related: rice)',
#  'Oryza sativa (related: rice) (non-host bioassay: tobacco)',
#  'Oryza sativa (related: rice) (non-host bioassay: yeast)',
#  'Ovis aries (related: sheep)',
#  'Paralichthys olivaceus (related: japanese flounder)',
#  'Pelargonium x hortorum (related: zonal pelargonium)',
#  'Penaeus monodon (related: black tiger shrimp)',
#  'Penaeus vannamei (related: pacific white shrimp)',
#  'Periplaneta americana (related: american cockroach)',
#  'Persea americana (related: avocado)',
#  'Petroselinum crispum (related: parsley)',
#  'Petroselinum crispum (related: parsley) (non-host bioassay)',
#  'Phaseolus vulgaris (related: kidney bean)',
#  'Pieris brassicae (related: large cabbage white)',
#  'Pimephales promelas (related: fathead minnow)',
#  'Pinus contorta (related: lodgepole pine)',
#  'Pinus massoniana (related: chinese red pine)',
#  'Pinus sylvestris (related: scots pine)',
#  'Pinus thunbergii (related: japanese black pine)',
#  'Pisum sativum (related: pea)',
#  'Plutella xylostella (related: diamondback moth)',
#  'Populus alba (related: white poplar)',
#  'Populus x beijingensis (no common name found)',
#  'Populus x canadensis (related: carolina poplar)',
#  'Potorous tridactylus (related: long-nosed potoroo)',
#  'Prunus americana (related: goose plum)',
#  'Prunus armeniaca (related: apricot)',
#  'Prunus avium (related: sweet cherry)',
#  'Prunus domestica (related: plum)',
#  'Prunus dulcis (related: almond)',
#  'Prunus persica (related: peach)',
#  'Punica granatum (related: pomegranate)',
#  'Pyrus communis (related: pear)',
#  'Pyrus pyrifolia (related: sha li)',
#  'Raphanus sativus (related: radish)',
#  'Rattus (related: rat)',
#  'Rattus norvegicus (related: norway rat)',
#  'Rattus rattus (related: black rat)',
#  'Rhaphiolepis bibas (related: loquat)',
#  'Rhipicephalus microplus (related: southern cattle tick)',
#  'Rhizoctonia solani (no common name found)',
#  'Rhodotorula mucilaginosa (no common name found)',
#  'Riptortus pedestris (no common name found)',
#  'Rosa (no common name found)',
#  'Rosa odorata (related: tea rose)',
#  'Saccharum officinarum (related: sugarcane)',
#  'Scophthalmus maximus (related: turbot)',
#  'Secale cereale (related: rye)',
#  'Selenicereus trigonus (related: strawberry-pear)',
#  'Sitophilus oryzae (related: rice weevil)',
#  'Solanum chacoense (related: chaco potato)',
#  'Solanum huancabambense (no common name found)',
#  'Solanum lycopersicum (related: tomato)',
#  'Solanum lycopersicum (related: tomato) (non-host bioassay: pichia pastoris)',
#  'Solanum lycopersicum (related: tomato) (non-host bioassay: yeast)',
#  'Solanum melongena (related: eggplant)',
#  'Solanum microdontum (no common name found)',
#  'Solanum peruvianum (related: peruvian tomato)',
#  'Solanum torvum (related: turkey berry)',
#  'Solanum tuberosum (related: potato)',
#  'Solanum tuberosum (related: potato)(non-host bioassay: nicotiana benthamiana)',
#  'Solanum tuberosum (related: potato)(non-host bioassay: yeast)',
#  'Sorghum bicolor (related: sorghum)',
#  'Spodoptera exigua (related: beet armyworm)',
#  'Spodoptera frugiperda (related: fall armyworm)',
#  'Spodoptera littoralis (related: african cotton leafworm)',
#  'Stylosanthes (no common name found)',
#  'Stylosanthes guianensis (related: stylo)',
#  'Sus scrofa (related: pig)',
#  'Tagetes erecta (related: african marigold)',
#  'Tenebrio molitor (related: yellow mealworm)',
#  'Theobroma cacao (related: cacao)',
#  'Tribolium castaneum (related: red flour beetle)',
#  'Trichoplusia ni (related: cabbage looper)',
#  'Trichopodus trichopterus (related: three spot gourami)',
#  'Triticum (related: wheat)',
#  'Triticum aestivum (related: bread wheat)',
#  'Triticum aestivum x triticum timopheevi (related: common wheat x sanduri wheat)',
#  'Triticum turgidum (related: rivet wheat)',
#  'Vicia faba (related: fava bean)',
#  'Vitis (no common name found)',
#  'Vitis vinifera (related: wine grape)',
#  'Xenopsylla cheopis (related: oriental rat flea)',
#  'Zantedeschia aethiopica (related: arum-lily)',
#  'Zantedeschia elliottiana (no common name found)',
#  'Zea mays (related: maize)',
#  'Zea mays (related: maize) (non-host bioassay: nicotiana benthamiana)',
#  'Zea mays (related: maize) (non-host bioassay: yeast)',
#  'Ziziphus (no common name found)'}

# %% [markdown]
# ## Filter host species for human entries

# %%
human_phibase = phibase[phibase['Host species'] == "Homo sapiens (related: human)"]

# %%
human_phibase
# Out:
#           Record ID PHI_MolConn_ID Protein ID source Protein ID  \
# 193      Record 194        PHI:198           Uniprot     P46590
# 194      Record 195        PHI:198           Uniprot     P46590
# 258      Record 259        PHI:252           Uniprot     Q5A7S7
# 483      Record 484        PHI:453           Uniprot     Q5ACU3
# 500      Record 501        PHI:468           Uniprot     Q6VBJ0
# ...             ...            ...               ...        ...
# 18184  Record 18185       PHI:7051           Uniprot     Q8DTF1
# 18185  Record 18186       PHI:7052           Uniprot     Q8DTB7
# 18186  Record 18187       PHI:7053           Uniprot     P08987
# 18187  Record 18188       PHI:7054           Uniprot     P13470
# 18188  Record 18189       PHI:7055           Uniprot     P49331
#
#       Gene ID source     Gene ID AA sequence NT sequence Sequence Strain  \
# 193             EMBL    AAC41649                                    B792
# 194             EMBL    AAC41649                                    B792
# 258             EMBL    EAK98810                                  SC5314
# 483             EMBL    EAL00423                                  SC5314
# 500             EMBL    AAQ82691                                     NaN
# ...              ...         ...         ...         ...             ...
# 18184        Genbank  AE014973_2                                   UA159
# 18185        Genbank  AE014976_8                                   UA159
# 18186        Genbank  AE014940_1                                   UA159
# 18187        Genbank  AE014940_2                                   UA159
# 18188        Genbank  AE014932_2                                   UA159
#
#        Gene  ...                                 Ref. detail  \
# 193    ALS1  ...                                         NaN
# 194    ALS1  ...                                         NaN
# 258    FKH2  ...                                         NaN
# 483    PMT5  ...                                         NaN
# 500    EPA1  ...                                         NaN
# ...     ...  ...                                         ...
# 18184  gbpC  ...  Infect Immun. 2016 Oct 17;84(11):3206-3219
# 18185  epsC  ...  Infect Immun. 2016 Oct 17;84(11):3206-3219
# 18186  gtfB  ...  Infect Immun. 2016 Oct 17;84(11):3206-3219
# 18187  gtfC  ...  Infect Immun. 2016 Oct 17;84(11):3206-3219
# 18188  gtfD  ...  Infect Immun. 2016 Oct 17;84(11):3206-3219
#
#                   Author email  \
# 193                        NaN
# 194                        NaN
# 258                        NaN
# 483                        NaN
# 500                        NaN
# ...                        ...
# 18184  rmgraner@fop.unicamp.br
# 18185  rmgraner@fop.unicamp.br
# 18186  rmgraner@fop.unicamp.br
# 18187  rmgraner@fop.unicamp.br
# 18188  rmgraner@fop.unicamp.br
#
#                                                 Comments Author reference  \
# 193                Buccal reconstituted human epithelium              NaN
# 194               Human umbilical vein endothelial cells              NaN
# 258        Forkhead Transcription Factor. Tissue Culture    Benson et al.
# 483                         Engineered human oral mucosa  Rouabhia et al.
# 500           Reduced adhesion to human epithelial cells    Cormack et al
# ...                                                  ...              ...
# 18184  UAcov showed increased exvivo survival in huma...   L A Alves 2016
# 18185  UAcov showed increased exvivo survival in huma...   L A Alves 2016
# 18186  UAcov showed increased exvivo survival in huma...   L A Alves 2016
# 18187  UAcov showed increased exvivo survival in huma...   L A Alves 2016
# 18188  UAcov showed increased exvivo survival in huma...   L A Alves 2016
#
#          Year Curation details  \
# 193       NaN              NaN
# 194       NaN              NaN
# 258    2002.0              NaN
# 483    2005.0              NaN
# 500    1999.0              NaN
# ...       ...              ...
# 18184  2016.0          6 genes
# 18185  2016.0          6 genes
# 18186  2016.0          6 genes
# 18187  2016.0          6 genes
# 18188  2016.0          6 genes
#
#                                             File name          Batch no.  \
# 193                                               NaN  PHI-base Vers.3.3
# 194                                               NaN  PHI-base Vers.3.3
# 258                                               NaN  PHI-base Vers.3.3
# 483                                               NaN  PHI-base Vers.3.3
# 500                                               NaN  PHI-base Vers.3.3
# ...                                               ...                ...
# 18184  Alves-2016-CovR regulates Streptococcus mutans         BATCH_067B
# 18185  Alves-2016-CovR regulates Streptococcus mutans         BATCH_067B
# 18186  Alves-2016-CovR regulates Streptococcus mutans         BATCH_067B
# 18187  Alves-2016-CovR regulates Streptococcus mutans         BATCH_067B
# 18188  Alves-2016-CovR regulates Streptococcus mutans         BATCH_067B
#
#        Curation date Curator organization
# 193            38476                 Rres
# 194            38476                 Rres
# 258            38476                 Rres
# 483            39206                 Rres
# 500            39206                 Rres
# ...              ...                  ...
# 18184         May-17                   MC
# 18185         May-17                   MC
# 18186         May-17                   MC
# 18187         May-17                   MC
# 18188         May-17                   MC
#
# [1135 rows x 66 columns]

# %%
set(human_phibase['Host species'].values)
# Out:
# {'Homo sapiens (related: human)'}

# %%
print(f'Number of entries for humans in phibase is {len(human_phibase)}.')
# Out:
# Number of entries for humans in phibase is 1135.

# %%
print('The pathogens in PhiBASE for humans')
set(human_phibase['Pathogen species'].values)
# Out:
# The pathogens in PhiBASE for humans
# {'Acinetobacter baumannii',
#  'Actinobacillus pleuropneumoniae',
#  'Aspergillus fumigatus',
#  'Bacillus cereus',
#  'Bordetella bronchiseptica',
#  'Bordetella pertussis',
#  'Borreliella burgdorferi',
#  'Brucella abortus',
#  'Brucella melitensis',
#  'Burkholderia cenocepacia',
#  'Burkholderia contaminans',
#  'Burkholderia pseudomallei',
#  'Campylobacter jejuni',
#  'Candida albicans',
#  'Candida glabrata',
#  'Candida parapsilosis',
#  'Chlamydia pneumoniae',
#  'Chlamydia trachomatis',
#  'Citrobacter rodentium',
#  'Clostridioides difficile',
#  'Corynebacterium diphtheriae',
#  'Corynebacterium ulcerans',
#  'Coxiella burnetii',
#  'Cronobacter turicensis',
#  'Cronobacter universalis',
#  'Cryptococcus neoformans',
#  'Edwardsiella tarda',
#  'Enterococcus faecalis',
#  'Escherichia coli',
#  'Exophiala dermatitidis',
#  'Francisella tularensis',
#  'Haemophilus ducreyi',
#  'Haemophilus influenzae',
#  'Helicobacter pylori',
#  'Kingella kingae',
#  'Klebsiella pneumoniae',
#  'Lactococcus lactis',
#  'Legionella pneumophila',
#  'Leishmania mexicana',
#  'Leptospira interrogans',
#  'Listeria monocytogenes',
#  'Mycobacterium avium',
#  'Mycobacterium marinum',
#  'Mycobacterium tuberculosis',
#  'Mycolicibacterium smegmatis',
#  'Mycoplasma agalactiae',
#  'Mycoplasma gallisepticum',
#  'Neisseria gonorrhoeae',
#  'Neisseria meningitidis',
#  'Paracoccidioides brasiliensis',
#  'Plasmodium falciparum',
#  'Porphyromonas gingivalis',
#  'Pseudomonas aeruginosa',
#  'Ralstonia pickettii',
#  'Salmonella enterica',
#  'Serratia marcescens',
#  'Shigella flexneri',
#  'Staphylococcus aureus',
#  'Staphylococcus lugdunensis',
#  'Streptococcus agalactiae',
#  'Streptococcus mutans',
#  'Streptococcus pneumoniae',
#  'Streptococcus pyogenes',
#  'Streptococcus suis',
#  'Toxoplasma gondii',
#  'Trichophyton rubrum',
#  'Vibrio cholerae',
#  'Vibrio parahaemolyticus',
#  'Yersinia enterocolitica',
#  'Yersinia pestis',
#  'Yersinia pseudotuberculosis'}

# %%
human_phibase.drop(['Gene ID', 'Gene ID source', 'NT sequence', 'Chr location', 'Gene/Protein modification', 'Modified gene/protein Id'], axis=1)
# Out:
#           Record ID PHI_MolConn_ID Protein ID source Protein ID AA sequence  \
# 193      Record 194        PHI:198           Uniprot     P46590
# 194      Record 195        PHI:198           Uniprot     P46590
# 258      Record 259        PHI:252           Uniprot     Q5A7S7
# 483      Record 484        PHI:453           Uniprot     Q5ACU3
# 500      Record 501        PHI:468           Uniprot     Q6VBJ0
# ...             ...            ...               ...        ...         ...
# 18184  Record 18185       PHI:7051           Uniprot     Q8DTF1
# 18185  Record 18186       PHI:7052           Uniprot     Q8DTB7
# 18186  Record 18187       PHI:7053           Uniprot     P08987
# 18187  Record 18188       PHI:7054           Uniprot     P13470
# 18188  Record 18189       PHI:7055           Uniprot     P49331
#
#       Sequence Strain  Gene Interacting partner(s) Interacting partner(s) Id  \
# 193              B792  ALS1                    NaN                       NaN
# 194              B792  ALS1                    NaN                       NaN
# 258            SC5314  FKH2                    NaN                       NaN
# 483            SC5314  PMT5                    NaN                       NaN
# 500               NaN  EPA1                    NaN                       NaN
# ...               ...   ...                    ...                       ...
# 18184           UA159  gbpC                    NaN                       NaN
# 18185           UA159  epsC                    NaN                       NaN
# 18186           UA159  gtfB                    NaN                       NaN
# 18187           UA159  gtfC                    NaN                       NaN
# 18188           UA159  gtfD                    NaN                       NaN
#
#         Multiple mutation  ...                                 Ref. detail  \
# 193                   NaN  ...                                         NaN
# 194                   NaN  ...                                         NaN
# 258                   NaN  ...                                         NaN
# 483                   NaN  ...                                         NaN
# 500                   NaN  ...                                         NaN
# ...                   ...  ...                                         ...
# 18184                 NaN  ...  Infect Immun. 2016 Oct 17;84(11):3206-3219
# 18185                 NaN  ...  Infect Immun. 2016 Oct 17;84(11):3206-3219
# 18186  PHI:7054; PHI:7055  ...  Infect Immun. 2016 Oct 17;84(11):3206-3219
# 18187  PHI:7053; PHI:7055  ...  Infect Immun. 2016 Oct 17;84(11):3206-3219
# 18188  PHI:7053; PHI:7054  ...  Infect Immun. 2016 Oct 17;84(11):3206-3219
#
#                   Author email  \
# 193                        NaN
# 194                        NaN
# 258                        NaN
# 483                        NaN
# 500                        NaN
# ...                        ...
# 18184  rmgraner@fop.unicamp.br
# 18185  rmgraner@fop.unicamp.br
# 18186  rmgraner@fop.unicamp.br
# 18187  rmgraner@fop.unicamp.br
# 18188  rmgraner@fop.unicamp.br
#
#                                                 Comments Author reference  \
# 193                Buccal reconstituted human epithelium              NaN
# 194               Human umbilical vein endothelial cells              NaN
# 258        Forkhead Transcription Factor. Tissue Culture    Benson et al.
# 483                         Engineered human oral mucosa  Rouabhia et al.
# 500           Reduced adhesion to human epithelial cells    Cormack et al
# ...                                                  ...              ...
# 18184  UAcov showed increased exvivo survival in huma...   L A Alves 2016
# 18185  UAcov showed increased exvivo survival in huma...   L A Alves 2016
# 18186  UAcov showed increased exvivo survival in huma...   L A Alves 2016
# 18187  UAcov showed increased exvivo survival in huma...   L A Alves 2016
# 18188  UAcov showed increased exvivo survival in huma...   L A Alves 2016
#
#          Year Curation details  \
# 193       NaN              NaN
# 194       NaN              NaN
# 258    2002.0              NaN
# 483    2005.0              NaN
# 500    1999.0              NaN
# ...       ...              ...
# 18184  2016.0          6 genes
# 18185  2016.0          6 genes
# 18186  2016.0          6 genes
# 18187  2016.0          6 genes
# 18188  2016.0          6 genes
#
#                                             File name          Batch no.  \
# 193                                               NaN  PHI-base Vers.3.3
# 194                                               NaN  PHI-base Vers.3.3
# 258                                               NaN  PHI-base Vers.3.3
# 483                                               NaN  PHI-base Vers.3.3
# 500                                               NaN  PHI-base Vers.3.3
# ...                                               ...                ...
# 18184  Alves-2016-CovR regulates Streptococcus mutans         BATCH_067B
# 18185  Alves-2016-CovR regulates Streptococcus mutans         BATCH_067B
# 18186  Alves-2016-CovR regulates Streptococcus mutans         BATCH_067B
# 18187  Alves-2016-CovR regulates Streptococcus mutans         BATCH_067B
# 18188  Alves-2016-CovR regulates Streptococcus mutans         BATCH_067B
#
#       Curation date Curator organization
# 193           38476                 Rres
# 194           38476                 Rres
# 258           38476                 Rres
# 483           39206                 Rres
# 500           39206                 Rres
# ...             ...                  ...
# 18184        May-17                   MC
# 18185        May-17                   MC
# 18186        May-17                   MC
# 18187        May-17                   MC
# 18188        May-17                   MC
#
# [1135 rows x 60 columns]

# %%
import panel as pn
pn.extension('tabulator')
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
human_phibase_widget = pn.widgets.DataFrame(human_phibase, autosize_mode='fit_columns', name='Human Phibase Interactions')
human_phibase_widget
# Out:
# DataFrame(autosize_mode='fit_columns', name='Human Phibase I..., value=          Record I...)
